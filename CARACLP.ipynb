# %%
python (version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JAHGUI~1\AppData\Local\Temp/ipykernel_22664/3032752849.py in <module>
# ----> 1 python (version)
#
# NameError: name 'python' is not defined

# %%
import getpass
print(getpass.getuser())
# Out:
# JAH GUIDE

# %%
conda list anaconda
# Out:
# # packages in environment at C:\Anaconda:
# #
# # Name                    Version                   Build  Channel
# anaconda                  2021.11                  py39_0
# anaconda-client           1.9.0            py39haa95532_0
# anaconda-navigator        2.1.1                    py39_0
# anaconda-project          0.10.1             pyhd3eb1b0_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import platform

# %%
print (platform.python_version())
# Out:
# 3.9.7

# %%
platform.machine()
# Out:
# 'AMD64'

# %%
platform.node()
# Out:
# 'LAPTOP-6J532B6L'

# %%
platform.architecture()
# Out:
# ('64bit', 'WindowsPE')

# %%
platform.version()
# Out:
# '10.0.22000'

# %%
platform.uname()
# Out:
# uname_result(system='Windows', node='LAPTOP-6J532B6L', release='10', version='10.0.22000', machine='AMD64')

# %%
import platform

print ('Descripcion:'), platform.uname()

print
print ('Sistema   :'), platform.system()
print ('Red       :'), platform.node()
print ('Version   :'), platform.version()
print ('Tipo      :'), platform.machine()
print ('Procesador:'), platform.processor()
# Out:
# Descripcion:
# Sistema   :
# Red       :
# Version   :
# Tipo      :
# Procesador:
# (None, 'AMD64 Family 23 Model 24 Stepping 1, AuthenticAMD')
